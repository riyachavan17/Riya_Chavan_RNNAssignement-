# %%
# RNN for Educational Text Classification and Next Word Generation

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# -------------------- PHASE 1: DATASET CREATION --------------------

# Sample synthetic dataset for classification
texts = [
    "Algebra teaches us about variables and equations.",
    "The cell is the basic unit of life.",
    "World War II ended in 1945.",
    "Photosynthesis is essential for plant life.",
    "Calculus helps in finding areas under curves.",
    "Newton discovered gravity.",
    "The French Revolution changed Europe.",
    "Multiplication is repeated addition.",
    "The water cycle involves evaporation and precipitation.",
    "Pythagorean theorem is used in right-angle triangles."
]
labels = ["Math", "Science", "History", "Science", "Math", "Science", "History", "Math", "Science", "Math"]

# Long text for generation task (focus on History)
history_corpus = """
The French Revolution was a period of radical social and political change in France. It began in 1789 when revolutionaries stormed the Bastille, a state prison in Paris. The revolution led to the end of monarchy and rise of democracy. Important figures like Robespierre and Napoleon played major roles. The revolution introduced concepts of liberty, equality, and fraternity, inspiring future movements around the world.
"""

# -------------------- PHASE 2: TEXT PREPROCESSING --------------------

# Classification Preprocessing
tokenizer_cls = Tokenizer()
tokenizer_cls.fit_on_texts(texts)
sequences = tokenizer_cls.texts_to_sequences(texts)
padded_cls = pad_sequences(sequences, padding='post')
vocab_size_cls = len(tokenizer_cls.word_index) + 1

label_enc = LabelEncoder()
encoded_labels = label_enc.fit_transform(labels)

X_train, X_test, y_train, y_test = train_test_split(padded_cls, encoded_labels, test_size=0.2, random_state=42)

# Generation Preprocessing
tokenizer_gen = Tokenizer()
tokenizer_gen.fit_on_texts([history_corpus])
total_words = len(tokenizer_gen.word_index) + 1
input_sequences = []

corpus = history_corpus.lower().split(".")
for line in corpus:
    tokens = tokenizer_gen.texts_to_sequences([line])[0]
    for i in range(1, len(tokens)):
        n_gram_sequence = tokens[:i+1]
        input_sequences.append(n_gram_sequence)

max_seq_len = max([len(x) for x in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre')
X_gen = input_sequences[:, :-1]
y_gen = tf.keras.utils.to_categorical(input_sequences[:, -1], num_classes=total_words)

# -------------------- PHASE 3: MODEL BUILDING --------------------

# Classification Model
model_cls = Sequential([
    Embedding(input_dim=vocab_size_cls, output_dim=32, input_length=padded_cls.shape[1]),
    SimpleRNN(32),
    Dense(3, activation='softmax')
])

model_cls.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Generation Model
model_gen = Sequential([
    Embedding(total_words, 32, input_length=max_seq_len - 1),
    SimpleRNN(64),
    Dense(total_words, activation='softmax')
])

model_gen.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# -------------------- PHASE 4: TRAINING AND EVALUATION --------------------

# Train Classification
model_cls.fit(X_train, y_train, epochs=20, verbose=1)
loss, accuracy = model_cls.evaluate(X_test, y_test)
print("\nClassification Accuracy:", accuracy)

# Train Generation
model_gen.fit(X_gen, y_gen, epochs=50, verbose=1)

# Text Generation
def generate_text(seed_text, next_words=20):
    for _ in range(next_words):
        token_list = tokenizer_gen.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_seq_len-1, padding='pre')
        predicted = np.argmax(model_gen.predict(token_list, verbose=0), axis=-1)
        output_word = ""
        for word, index in tokenizer_gen.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# Example generation
seed = "The French Revolution began with a major"
print("\nGenerated Text:\n", generate_text(seed))
# Out:
# Epoch 1/20
# C:\Users\riyac\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.1250 - loss: 1.1063
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2500 - loss: 1.0685
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5000 - loss: 1.0318
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7500 - loss: 0.9956
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8750 - loss: 0.9596
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.9233
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.8866
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.8494
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.8114
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.7726
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.7332
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.6930
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.6523
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.6111
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.5696
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.5281
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.4869
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.4464
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.4068
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.3687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.0000e+00 - loss: 1.7106
#
# Classification Accuracy: 0.0
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.0434 - loss: 3.9037
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.0556 - loss: 3.8522
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0782 - loss: 3.8258
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.1216 - loss: 3.7850
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.1008 - loss: 3.7693
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1321 - loss: 3.7379
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1208 - loss: 3.6881
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.0999 - loss: 3.6581
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1208 - loss: 3.6246
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1529 - loss: 3.5727
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1538 - loss: 3.5535
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.1434 - loss: 3.5284
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1538 - loss: 3.4869
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1442 - loss: 3.4404
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1547 - loss: 3.3905
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2103 - loss: 3.3499
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3284 - loss: 3.2487
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3501 - loss: 3.2068
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2971 - loss: 3.2076
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3189 - loss: 3.1364
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3293 - loss: 3.0877
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3510 - loss: 3.0252
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.3406 - loss: 2.9996
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2989 - loss: 2.9900
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.3632 - loss: 2.9023
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4048 - loss: 2.8262
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3953 - loss: 2.7893
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4283 - loss: 2.7172
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4509 - loss: 2.6942
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4848 - loss: 2.6215
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5074 - loss: 2.6029
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5500 - loss: 2.5191
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5916 - loss: 2.4014
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5812 - loss: 2.3703
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5613 - loss: 2.3426
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5726 - loss: 2.2904
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5621 - loss: 2.2370
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5943 - loss: 2.1524
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6160 - loss: 2.1192
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6490 - loss: 2.0523
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6907 - loss: 1.9454
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6707 - loss: 1.9662
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6933 - loss: 1.9337
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7255 - loss: 1.8652
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7445 - loss: 1.7245
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7037 - loss: 1.7680
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7472 - loss: 1.7106
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7368 - loss: 1.6579
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7472 - loss: 1.6210
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7906 - loss: 1.5461
#
# Generated Text:
#  The French Revolution began with a major of and social and political change in france around the world movements france prison world prison france it democracy future
